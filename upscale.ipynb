# %%
# %load_ext autoreload
# %autoreload 2

# %%
from crystal_clear.upscale import upscale, FeatureLoss
from pydub import AudioSegment
from fastai.basic_train import load_learner

# %%
learn = load_learner('./data/crappified/dataset_1/models_export', '1a3.pkl')

# %% [markdown]
# # Change audio file path here:

# %%
path_file = './samples/crappified/1930_1.mp3'

# %%
song = AudioSegment.from_file(path_file)
upscaled_song = upscale(path_file, learner=learn)
print('Original audio file :')
display(song)
print('Upscaled audio file :')
display(upscaled_song)
upscaled_song.export(f'./generated_file/{os.path.basename(path_file)}', format='mp3')
pass
# Out:
# 100%|██████████| 82/82 [00:01<00:00, 70.99it/s]
# Original audio file :
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
# Upscaled audio file :
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
